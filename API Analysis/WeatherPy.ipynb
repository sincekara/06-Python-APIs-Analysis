# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#Note: Since the codes in this and the next section came with the default homework files, no change has been done.
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#Note: Since the codes in this and the next section came with the default homework files, no change has been done.
# List for holding lat_lngs and cities

lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#entering url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# Producing lists for different API parameters 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# setting counter 
record = 1

#printing statement
print(f"Beginning Data Retrieval | Cities")
print(f"---------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record}      | {city_record}")
       
        
        # Increasing the counter 
        record= record + 1
           
    # if there is no record, "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval | Cities
# ---------------------------------
# Processing Record 1      | Valdivia
# Processing Record 2      | Jalcocotan
# Processing Record 3      | Vaini
# Processing Record 4      | Castro
# Processing Record 5      | Carbonia
# Processing Record 6      | Dikson
# Processing Record 7      | Bredasdorp
# City not found. Skipping...
# Processing Record 8      | Saint-Philippe
# Processing Record 9      | Hermanus
# Processing Record 10      | Ponta do Sol
# Processing Record 11      | Kaihua
# Processing Record 12      | Yellowknife
# Processing Record 13      | Hilo
# City not found. Skipping...
# Processing Record 14      | Salinopolis
# Processing Record 15      | Ushuaia
# Processing Record 16      | Punta Arenas
# City not found. Skipping...
# Processing Record 17      | Cabo San Lucas
# Processing Record 18      | Ribeira Grande
# Processing Record 19      | Busselton
# Processing Record 20      | Norman Wells
# Processing Record 21      | East London
# Processing Record 22      | Poya
# Processing Record 23      | Mataura
# Processing Record 24      | Chokurdakh
# Processing Record 25      | Albany
# Processing Record 26      | Port Alfred
# Processing Record 27      | Pevek
# Processing Record 28      | Namatanai
# City not found. Skipping...
# Processing Record 29      | Dispur
# Processing Record 30      | Asyut
# Processing Record 31      | Hualmay
# Processing Record 32      | Bereznik
# Processing Record 33      | Oranjemund
# Processing Record 34      | Lebu
# Processing Record 35      | Haapiti
# Processing Record 36      | Mount Gambier
# Processing Record 37      | Rikitea
# Processing Record 38      | Hasaki
# Processing Record 39      | Kodiak
# Processing Record 40      | New Norfolk
# Processing Record 41      | Atuona
# Processing Record 42      | Upernavik
# Processing Record 43      | Kapaa
# Processing Record 44      | Tiksi
# Processing Record 45      | Tuktoyaktuk
# Processing Record 46      | Carnarvon
# Processing Record 47      | Biloela
# Processing Record 48      | Thompson
# Processing Record 49      | Zhezkazgan
# Processing Record 50      | Goderich
# City not found. Skipping...
# Processing Record 51      | Morant Bay
# Processing Record 52      | Rio Gallegos
# Processing Record 53      | Jamestown
# Processing Record 54      | Narsaq
# Processing Record 55      | Bathsheba
# City not found. Skipping...
# Processing Record 56      | Hobart
# Processing Record 57      | Hithadhoo
# Processing Record 58      | San Javier
# Processing Record 59      | San Jose
# Processing Record 60      | Mitu
# Processing Record 61      | Tautira
# Processing Record 62      | Mahebourg
# Processing Record 63      | Qasigiannguit
# City not found. Skipping...
# Processing Record 64      | Matamoros
# Processing Record 65      | Imeni Poliny Osipenko
# Processing Record 66      | Torbay
# Processing Record 67      | Butaritari
# Processing Record 68      | Tasiilaq
# Processing Record 69      | Xunchang
# Processing Record 70      | Luanda
# Processing Record 71      | Cape Town
# Processing Record 72      | Chuy
# Processing Record 73      | Cockburn Town
# Processing Record 74      | Barrow
# Processing Record 75      | Zyryanka
# Processing Record 76      | Kahului
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 77      | Norrtalje
# City not found. Skipping...
# Processing Record 78      | Arraial do Cabo
# Processing Record 79      | Havelock
# Processing Record 80      | Avarua
# Processing Record 81      | Rocha
# Processing Record 82      | Saint George
# Processing Record 83      | Pacific Grove
# Processing Record 84      | Leningradskiy
# City not found. Skipping...
# Processing Record 85      | Nantucket
# Processing Record 86      | Bluff
# Processing Record 87      | Bojnurd
# Processing Record 88      | Yar-Sale
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 89      | Orocue
# Processing Record 90      | Cordoba
# Processing Record 91      | Saint-Georges
# Processing Record 92      | Nuuk
# Processing Record 93      | Madimba
# Processing Record 94      | Guilin
# Processing Record 95      | Georgetown
# City not found. Skipping...
# Processing Record 96      | Longyearbyen
# Processing Record 97      | Pampa
# Processing Record 98      | Invermere
# Processing Record 99      | Ambilobe
# Processing Record 100      | Vaitape
# Processing Record 101      | Puerto Ayora
# Processing Record 102      | Say
# Processing Record 103      | Khatanga
# City not found. Skipping...
# Processing Record 104      | Vorotynets
# Processing Record 105      | Lucea
# Processing Record 106      | Baranchinskiy
# Processing Record 107      | Cooma
# Processing Record 108      | Ilulissat
# Processing Record 109      | Alexandria
# City not found. Skipping...
# Processing Record 110      | Vostok
# Processing Record 111      | Kaitangata
# Processing Record 112      | Fallon
# Processing Record 113      | Saint-Pierre
# Processing Record 114      | Kavieng
# Processing Record 115      | Sovetskiy
# Processing Record 116      | Mecca
# Processing Record 117      | Camacha
# Processing Record 118      | Road Town
# City not found. Skipping...
# Processing Record 119      | Nome
# Processing Record 120      | Orlik
# Processing Record 121      | Cherskiy
# Processing Record 122      | Mar del Plata
# City not found. Skipping...
# Processing Record 123      | La Ronge
# Processing Record 124      | Ipixuna
# Processing Record 125      | Broome
# Processing Record 126      | Timra
# Processing Record 127      | Flinders
# Processing Record 128      | Raton
# Processing Record 129      | Xacmaz
# Processing Record 130      | Grand Gaube
# Processing Record 131      | Cortez
# Processing Record 132      | Paamiut
# Processing Record 133      | Provideniya
# City not found. Skipping...
# Processing Record 134      | Qaanaaq
# Processing Record 135      | Faanui
# Processing Record 136      | Pangnirtung
# Processing Record 137      | Hofn
# Processing Record 138      | Ponta Delgada
# Processing Record 139      | Tura
# Processing Record 140      | Artesia
# Processing Record 141      | Gazanjyk
# Processing Record 142      | Pasir Gudang
# Processing Record 143      | Necochea
# Processing Record 144      | Biak
# Processing Record 145      | Kyzyl-Suu
# Processing Record 146      | Solnechnyy
# City not found. Skipping...
# Processing Record 147      | Meulaboh
# City not found. Skipping...
# Processing Record 148      | Poum
# Processing Record 149      | Digha
# Processing Record 150      | Pangody
# Processing Record 151      | Bethel
# Processing Record 152      | Yaan
# Processing Record 153      | Nikolskoye
# City not found. Skipping...
# Processing Record 154      | Beyneu
# Processing Record 155      | Elizabeth City
# Processing Record 156      | Maudaha
# Processing Record 157      | Anadyr
# Processing Record 158      | Andros
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 159      | Sfantu Gheorghe
# Processing Record 160      | Panormos
# Processing Record 161      | Butia
# City not found. Skipping...
# Processing Record 162      | Cayenne
# Processing Record 163      | Naze
# Processing Record 164      | Otane
# Processing Record 165      | Mezen
# City not found. Skipping...
# Processing Record 166      | Loandjili
# Processing Record 167      | Ouesso
# Processing Record 168      | Kieta
# Processing Record 169      | Komsomolskiy
# Processing Record 170      | Severo-Kurilsk
# Processing Record 171      | College
# City not found. Skipping...
# Processing Record 172      | Lorengau
# Processing Record 173      | Cidreira
# Processing Record 174      | Alice Town
# Processing Record 175      | Katsuura
# Processing Record 176      | Vestmannaeyjar
# Processing Record 177      | Aklavik
# Processing Record 178      | Kiama
# Processing Record 179      | Roald
# Processing Record 180      | Sao Filipe
# Processing Record 181      | Andros Town
# Processing Record 182      | Atar
# Processing Record 183      | Charters Towers
# Processing Record 184      | Airai
# Processing Record 185      | Porangatu
# Processing Record 186      | Rolla
# Processing Record 187      | Richards Bay
# Processing Record 188      | Wasilla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 189      | Antofagasta
# Processing Record 190      | Bowen
# Processing Record 191      | Turukhansk
# Processing Record 192      | Constitucion
# City not found. Skipping...
# Processing Record 193      | Port-Cartier
# Processing Record 194      | Isangel
# Processing Record 195      | Agirish
# Processing Record 196      | Felanitx
# Processing Record 197      | Sobolevo
# Processing Record 198      | Sorong
# Processing Record 199      | Geraldton
# City not found. Skipping...
# Processing Record 200      | Xuanhua
# Processing Record 201      | Beringovskiy
# Processing Record 202      | Dicabisagan
# Processing Record 203      | Morondava
# Processing Record 204      | Egvekinot
# Processing Record 205      | Gizo
# Processing Record 206      | Saskylakh
# Processing Record 207      | Dharchula
# Processing Record 208      | Deqing
# Processing Record 209      | Zaozerne
# Processing Record 210      | Tuatapere
# Processing Record 211      | Lithakia
# Processing Record 212      | Ovsyanka
# Processing Record 213      | Hambantota
# Processing Record 214      | Esperance
# Processing Record 215      | Halifax
# Processing Record 216      | Piacabucu
# Processing Record 217      | Pandan
# Processing Record 218      | Leshukonskoye
# Processing Record 219      | Tchaourou
# Processing Record 220      | Khani
# Processing Record 221      | Portland
# Processing Record 222      | The Pas
# Processing Record 223      | Haskovo
# Processing Record 224      | Bonthe
# City not found. Skipping...
# Processing Record 225      | Cacheu
# Processing Record 226      | Paita
# Processing Record 227      | Bubaque
# Processing Record 228      | Ndola
# Processing Record 229      | Chapais
# Processing Record 230      | Yulara
# Processing Record 231      | Senanga
# Processing Record 232      | Lavrentiya
# Processing Record 233      | Gat
# Processing Record 234      | Chaman
# Processing Record 235      | Predivinsk
# Processing Record 236      | Hisar
# Processing Record 237      | Cairns
# Processing Record 238      | Anaconda
# Processing Record 239      | Yertarskiy
# Processing Record 240      | Shakiso
# Processing Record 241      | Buala
# Processing Record 242      | Karakol
# Processing Record 243      | La Orilla
# Processing Record 244      | Dukat
# Processing Record 245      | Diamantino
# Processing Record 246      | Zhigansk
# Processing Record 247      | Bilma
# Processing Record 248      | San Cristobal
# Processing Record 249      | Sambava
# Processing Record 250      | Galle
# Processing Record 251      | Tilichiki
# Processing Record 252      | Powassan
# Processing Record 253      | Troitskoye
# Processing Record 254      | Suez
# Processing Record 255      | Mercedes
# Processing Record 256      | Faya
# Processing Record 257      | Bilibino
# Processing Record 258      | Sheboygan
# Processing Record 259      | Zilair
# Processing Record 260      | Vagur
# Processing Record 261      | Balta
# Processing Record 262      | Dingle
# Processing Record 263      | Kupang
# Processing Record 264      | Krasnovishersk
# Processing Record 265      | Kloulklubed
# Processing Record 266      | Deputatskiy
# Processing Record 267      | Alice Springs
# Processing Record 268      | Nara
# Processing Record 269      | Ust-Tsilma
# Processing Record 270      | Novopokrovka
# Processing Record 271      | Usinsk
# Processing Record 272      | Krasnokamensk
# Processing Record 273      | Vanavara
# Processing Record 274      | Awbari
# City not found. Skipping...
# Processing Record 275      | Almeirim
# Processing Record 276      | Great Yarmouth
# Processing Record 277      | Bambous Virieux
# Processing Record 278      | Yerbogachen
# Processing Record 279      | Tbilisi
# Processing Record 280      | Port-Gentil
# City not found. Skipping...
# Processing Record 281      | Acapulco
# Processing Record 282      | Port Moresby
# Processing Record 283      | Codrington
# Processing Record 284      | Dzaoudzi
# Processing Record 285      | Hudson Bay
# Processing Record 286      | Gamba
# Processing Record 287      | Seymchan
# Processing Record 288      | Kaeo
# Processing Record 289      | Pouebo
# Processing Record 290      | Verkhnevilyuysk
# Processing Record 291      | Bougouni
# Processing Record 292      | Panzhihua
# Processing Record 293      | Hami
# Processing Record 294      | Kruisfontein
# Processing Record 295      | Vanimo
# Processing Record 296      | Labuhan
# Processing Record 297      | Vuktyl
# Processing Record 298      | Brokopondo
# Processing Record 299      | Ereymentau
# Processing Record 300      | Katobu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 301      | Bukachacha
# Processing Record 302      | Matara
# Processing Record 303      | Caravelas
# Processing Record 304      | Lagoa
# Processing Record 305      | Baker City
# Processing Record 306      | Victoria
# Processing Record 307      | Adrar
# Processing Record 308      | Luderitz
# Processing Record 309      | Steamboat Springs
# City not found. Skipping...
# Processing Record 310      | Ajdabiya
# Processing Record 311      | Tabou
# Processing Record 312      | Surat
# Processing Record 313      | Guerrero Negro
# Processing Record 314      | Makakilo City
# City not found. Skipping...
# Processing Record 315      | Vila Franca do Campo
# Processing Record 316      | Cabedelo
# Processing Record 317      | San Patricio
# City not found. Skipping...
# Processing Record 318      | Sinop
# Processing Record 319      | Boa Vista
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 320      | Lompoc
# Processing Record 321      | Svetlaya
# Processing Record 322      | Sabang
# Processing Record 323      | Kon Tum
# Processing Record 324      | Covington
# Processing Record 325      | Usatove
# Processing Record 326      | Ayagoz
# Processing Record 327      | Saldanha
# City not found. Skipping...
# Processing Record 328      | Marsh Harbour
# City not found. Skipping...
# Processing Record 329      | Moussoro
# Processing Record 330      | Ahipara
# Processing Record 331      | Udachnyy
# Processing Record 332      | Praia da Vitoria
# Processing Record 333      | Sarakhs
# Processing Record 334      | Seoul
# Processing Record 335      | Banda Aceh
# Processing Record 336      | Sulangan
# Processing Record 337      | Puerto Escondido
# Processing Record 338      | Maceio
# Processing Record 339      | Usogorsk
# Processing Record 340      | Xining
# City not found. Skipping...
# Processing Record 341      | Oleksandrivka
# Processing Record 342      | San Quintin
# Processing Record 343      | Tabas
# Processing Record 344      | Ixtapa
# Processing Record 345      | Byron Bay
# Processing Record 346      | Campbellton
# City not found. Skipping...
# Processing Record 347      | Manzanillo
# Processing Record 348      | Auki
# Processing Record 349      | Jackson
# Processing Record 350      | Sainte-Rose
# Processing Record 351      | Ambon
# City not found. Skipping...
# Processing Record 352      | Nueve de Julio
# City not found. Skipping...
# Processing Record 353      | Jiayuguan
# Processing Record 354      | High Rock
# Processing Record 355      | Hollins
# City not found. Skipping...
# Processing Record 356      | Vilyuysk
# City not found. Skipping...
# Processing Record 357      | Srednekolymsk
# Processing Record 358      | Liverpool
# City not found. Skipping...
# Processing Record 359      | Clyde River
# City not found. Skipping...
# Processing Record 360      | Palu
# Processing Record 361      | Berlevag
# Processing Record 362      | Omboue
# Processing Record 363      | Porbandar
# Processing Record 364      | Gualaquiza
# Processing Record 365      | Itoman
# Processing Record 366      | Pedernales
# City not found. Skipping...
# Processing Record 367      | Berdigestyakh
# Processing Record 368      | Beloha
# Processing Record 369      | Acheng
# Processing Record 370      | Mantua
# Processing Record 371      | Antalaha
# Processing Record 372      | Vila Velha
# Processing Record 373      | Shizuishan
# Processing Record 374      | Arlit
# City not found. Skipping...
# Processing Record 375      | Teahupoo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 376      | Nata
# Processing Record 377      | Salalah
# Processing Record 378      | Abha
# Processing Record 379      | Mizdah
# Processing Record 380      | Umm Lajj
# Processing Record 381      | Port Hardy
# City not found. Skipping...
# Processing Record 382      | Aztec
# Processing Record 383      | Klaksvik
# City not found. Skipping...
# Processing Record 384      | Lakshmipur
# Processing Record 385      | Camacari
# Processing Record 386      | Balabac
# Processing Record 387      | Aksu
# Processing Record 388      | Manubul
# Processing Record 389      | Avera
# Processing Record 390      | Sangod
# Processing Record 391      | Katangli
# Processing Record 392      | Vao
# City not found. Skipping...
# Processing Record 393      | Soyo
# Processing Record 394      | Diego de Almagro
# Processing Record 395      | Cessnock
# City not found. Skipping...
# Processing Record 396      | Kavaratti
# Processing Record 397      | Pecos
# Processing Record 398      | Nanfeng
# Processing Record 399      | Taoudenni
# Processing Record 400      | Ternate
# Processing Record 401      | Flin Flon
# Processing Record 402      | Hobyo
# Processing Record 403      | Namibe
# Processing Record 404      | Sola
# Processing Record 405      | Sur
# Processing Record 406      | Gamboma
# Processing Record 407      | Kayerkan
# Processing Record 408      | Kangaba
# Processing Record 409      | Milton
# Processing Record 410      | Oriximina
# Processing Record 411      | Ulladulla
# Processing Record 412      | Padang
# Processing Record 413      | Hovd
# Processing Record 414      | Punta Cardon
# Processing Record 415      | Narrabri
# Processing Record 416      | Bayir
# Processing Record 417      | Marawi
# Processing Record 418      | Lagunas
# Processing Record 419      | Tahoua
# City not found. Skipping...
# Processing Record 420      | Los Llanos de Aridane
# Processing Record 421      | Port Elizabeth
# Processing Record 422      | Ailigandi
# City not found. Skipping...
# Processing Record 423      | Brae
# Processing Record 424      | Qinzhou
# Processing Record 425      | Muros
# Processing Record 426      | Armidale
# Processing Record 427      | Kerva
# Processing Record 428      | Dunedin
# Processing Record 429      | Campbell River
# Processing Record 430      | Quatre Cocos
# Processing Record 431      | Kimbe
# Processing Record 432      | Iquique
# Processing Record 433      | Mehamn
# Processing Record 434      | Druzhba
# Processing Record 435      | Husavik
# Processing Record 436      | Cognac
# Processing Record 437      | Muli
# Processing Record 438      | Uruzgan
# Processing Record 439      | Yarim
# Processing Record 440      | Morehead
# Processing Record 441      | Akdepe
# City not found. Skipping...
# Processing Record 442      | Orotukan
# Processing Record 443      | Honningsvag
# Processing Record 444      | Xuddur
# Processing Record 445      | Emba
# Processing Record 446      | Peace River
# Processing Record 447      | Kargat
# Processing Record 448      | Souillac
# Processing Record 449      | Sisophon
# Processing Record 450      | Atherton
# Processing Record 451      | Xingtai
# City not found. Skipping...
# Processing Record 452      | Morris
# Processing Record 453      | Trecate
# Processing Record 454      | Phan Thiet
# Processing Record 455      | Port Hedland
# Processing Record 456      | Linhares
# Processing Record 457      | Bam
# Processing Record 458      | Alofi
# Processing Record 459      | Kutum
# Processing Record 460      | Ngudu
# Processing Record 461      | Barahona
# Processing Record 462      | Brownwood
# Processing Record 463      | Shchelkun
# Processing Record 464      | Qaqortoq
# Processing Record 465      | Lanzhou
# Processing Record 466      | Severnoye
# Processing Record 467      | Te Anau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 468      | Monte Alegre
# Processing Record 469      | Snezhnogorsk
# Processing Record 470      | Bud
# Processing Record 471      | Zhumadian
# Processing Record 472      | General Roca
# Processing Record 473      | Praia
# Processing Record 474      | Shingu
# Processing Record 475      | Axim
# Processing Record 476      | Mompos
# Processing Record 477      | Mae Sai
# Processing Record 478      | Honggang
# Processing Record 479      | Cartagena
# Processing Record 480      | Prieska
# Processing Record 481      | San Rafael
# City not found. Skipping...
# Processing Record 482      | Ancud
# Processing Record 483      | Lavumisa
# City not found. Skipping...
# Processing Record 484      | Birao
# Processing Record 485      | Kant
# Processing Record 486      | La Romana
# Processing Record 487      | Ozark
# Processing Record 488      | Bandundu
# City not found. Skipping...
# Processing Record 489      | Karratha
# Processing Record 490      | Kaseda
# Processing Record 491      | Benito Juarez
# Processing Record 492      | Dzhebariki-Khaya
# Processing Record 493      | Ribeira do Pombal
# Processing Record 494      | Beaverlodge
# Processing Record 495      | Krathum Baen
# Processing Record 496      | Am Timan
# Processing Record 497      | Kandrian
# Processing Record 498      | Haines Junction
# Processing Record 499      | Bibiani
# Processing Record 500      | Grenaa
# Processing Record 501      | Rio Grande
# Processing Record 502      | Okrika
# Processing Record 503      | Umm Kaddadah
# Processing Record 504      | Maues
# Processing Record 505      | Petropavlovsk-Kamchatskiy
# Processing Record 506      | Ambulu
# Processing Record 507      | Zuwarah
# Processing Record 508      | Bagru
# Processing Record 509      | Copacabana
# Processing Record 510      | Shitkino
# Processing Record 511      | Mangit
# Processing Record 512      | Yavatmal
# Processing Record 513      | Mayo
# Processing Record 514      | Brattvag
# Processing Record 515      | Abeche
# Processing Record 516      | Vardo
# Processing Record 517      | Sitka
# Processing Record 518      | Hamilton
# City not found. Skipping...
# Processing Record 519      | Lata
# Processing Record 520      | Saint Anthony
# Processing Record 521      | Panama City
# Processing Record 522      | Laguna
# Processing Record 523      | Isaka
# Processing Record 524      | Megion
# Processing Record 525      | Peruibe
# Processing Record 526      | Churapcha
# Processing Record 527      | Northam
# Processing Record 528      | High Level
# Processing Record 529      | Mackay
# Processing Record 530      | Kirkkonummi
# Processing Record 531      | Tukums
# Processing Record 532      | Fairbanks
# Processing Record 533      | Boldumsaz
# Processing Record 534      | Pampierstad
# Processing Record 535      | Ballina
# Processing Record 536      | Mnogovershinnyy

# %%
#creating a dictionary a dictonary with the lists generated
weather_conditions = {
    "City Name": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Latitude":lat, 
    "Longitude":lng, 
    "Max Temp.": max_temp,
    "Wind Speed":wind_speed
}

# establishing a dataframe including the above elements
weather_elements = pd.DataFrame(weather_conditions)

# displaying the dataframe 
weather_elements.count()
# Out:
# City Name     536
# Cloudiness    536
# Country       536
# Date          536
# Humidity      536
# Latitude      536
# Longitude     536
# Max Temp.     536
# Wind Speed    536
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#saving data to a CSV file
weather_elements.to_csv("output_data/cities.csv")

# displaying data frame 
weather_elements.head()
# Out:
#     City Name  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0    Valdivia           0      CL  1569541876        82    -39.81     -73.25
# 1  Jalcocotan          75      MX  1569541877        78     21.48    -105.10
# 2       Vaini         100      IN  1569541877        94     15.34      74.49
# 3      Castro           0      CL  1569541877        67    -42.48     -73.76
# 4    Carbonia           0      IT  1569541878        77     39.17       8.53
#
#    Max Temp.  Wind Speed
# 0      64.40        4.70
# 1      77.00       11.41
# 2      73.08        2.77
# 3      57.20        5.82
# 4      69.80       14.99

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#creating the scatter plots
plt.scatter(weather_elements["Latitude"], weather_elements["Max Temp."], marker="o", s=100, alpha = 0.75, edgecolor = "gold")

#locating the graph properties
plt.title("City Latitude and Max Temperature Comparison (08/25/2019)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("output_data/Latitude vs. Temperature Plot.png")

#displaying the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#creating the scatter plots
plt.scatter(weather_elements["Latitude"], weather_elements["Humidity"], marker="o", s=100, alpha = 0.75, edgecolor = "red")

#locating the graph properties
plt.title("City Latitude and Humidity Comparison (08/25/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("output_data/Latitude vs. Humidity Plot.png")

#displaying the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#creating the scatter plots
plt.scatter(weather_elements["Latitude"], weather_elements["Cloudiness"], marker="o", s=100, alpha = 0.75, edgecolor = "green")

#locating the graph properties
plt.title("City Latitude and Cloudiness Comparison (08/25/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("output_data/Latitude vs. Cloudiness Plot.png")

#displaying the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#creating the scatter plots
plt.scatter(weather_elements["Latitude"], weather_elements["Wind Speed"], marker="o", s=100, alpha = 0.75, edgecolor = "blue")

#locating the graph properties
plt.title("City Latitude and Wind Speed Comparison (08/25/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

#save the plot
plt.savefig("output_data/Latitude vs. Winds Speed Plot.png")

#displaying the plot
plt.show()

# %% [markdown]
# THREE OBSERVABLE TRENDS

# %% [markdown]
# The latitude vs. temperature plot tells us that, the max. temps increase from the poles towards the Equator in both North and South Hemisphere. This is called "Latitude Effect" in Geography (By the way, the cities in Southern Hemisphere have negative latitude numbers while the Northerners have positive). However, temperatures make a peak at around 20 degrees North latitude, not exactly at the equator line. This can be explained due to the different cooling and warming features of oceans and lands. Moreover, lands cover more areas in Nortern Hemisphere compared to the Southern one. Lands have low specific heat causing the existence more max. temps in the Northern Hemisphere.
#
# It seems that there is no strong correlation between latitude and humidity. The related plot shows a great variety of values at the same or similar latitudes. However, the humidity rates are slightly  more in Norhern Hemisphere compared to the Southern Hemisphere. It can be explained by the existance of more cities in the Northern Hemisphere because the Northern Hemisphere one has more lands then the South Hemisphere.
#
# Wind speed appears to vary between roughly 0-10 mph and has a tendency of slightly increasing from the equator towards the poles.
